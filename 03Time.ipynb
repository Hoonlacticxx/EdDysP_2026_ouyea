# %%
import time

segs = int(input("Cant. de segs a esperar: "))
time.sleep(segs)

print(f"Han pasado {segs} segundos")
# Out:
# Cant. de segs a esperar: 2
# Han pasado 2 segundos

# %%
hInicial = time.time()

for termino in range(10):
  time.sleep(segs)

print("Proceso simulado concluido")
dur = time.time() - hInicial
print(f"Tiempo de ejecucion: {dur}")
# Out:
# Proceso simulado concluido
# Tiempo de ejecucion: 20.002022981643677
