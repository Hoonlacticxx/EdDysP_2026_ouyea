# %%
diccionario_vacio = {}
diccionario_citas = {"T'Challa":"Wakanda por siempre!",
                     "Thanos":"Las decisiones dificles requieren voluntades fuertes",
                     "AMLO":"Me canso ganso"}

print(diccionario_citas)
# Out:
# {"T'Challa": 'Wakanda por siempre!', 'Thanos': 'Las decisiones dificles requieren voluntades fuertes', 'AMLO': 'Me canso ganso'}

# %%
print(diccionario_citas["Thanos"])
# Out:
# Las decisiones dificles requieren voluntades fuertes

# %%
diccionario_citas["Plankton"] = "¡Por fin tengo la fórmula de la cangreburger!"
print(diccionario_citas)
# Out:
# {"T'Challa": 'Wakanda por siempre!', 'Thanos': 'Las decisiones dificles requieren voluntades fuertes', 'AMLO': 'Me canso ganso', 'Plankton': '¡Por fin tengo la fórmula de la cangreburger!'}

# %%
del diccionario_citas["AMLO"]
print(diccionario_citas)
# Out:
# {"T'Challa": 'Wakanda por siempre!', 'Thanos': 'Las decisiones dificles requieren voluntades fuertes', 'Plankton': '¡Por fin tengo la fórmula de la cangreburger!'}

# %%
#Opción 1 : Todas las claves, solamente las claves
print(list(diccionario_citas.keys()))
# Out:
# ["T'Challa", 'Thanos', 'Plankton']

# %%
#Opción 2 : Todos los valores, solamente los valores
print(list(diccionario_citas.values()))
# Out:
# ['Wakanda por siempre!', 'Las decisiones dificles requieren voluntades fuertes', '¡Por fin tengo la fórmula de la cangreburger!']

# %%
#Opción 3 : Todos los elementos, elemento por elemento
print(list(diccionario_citas.items()))
# Out:
# [("T'Challa", 'Wakanda por siempre!'), ('Thanos', 'Las decisiones dificles requieren voluntades fuertes'), ('Plankton', '¡Por fin tengo la fórmula de la cangreburger!')]

# %%
print(dict([['Pedro', 23], ['Juan', 10]]))
# Out:
# {'Pedro': 23, 'Juan': 10}

# %%
print(diccionario_citas.get("Plankton"))
# Out:
# ¡Por fin tengo la fórmula de la cangreburger!

# %%
del diccionario_citas["Plankton"]
print(diccionario_citas)
# Out:
# {"T'Challa": 'Wakanda por siempre!', 'Thanos': 'Las decisiones dificles requieren voluntades fuertes'}
